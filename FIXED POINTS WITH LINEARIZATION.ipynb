# %% [markdown]
# # PRACTICE 4

# %% [markdown]
# ## 1 FIXED POINTS WITH LINEARIZATION

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
import pylab as pl


a, b, c, d = 0, 1, -2, -2
J = np.matrix([[a,b],[c,d]])
dJ = np.linalg.det(J)
tJ = np.trace(J)
k = tJ**2 - 4*dJ
epsFIX = 1e-6

if dJ < -epsFIX:
    print(' Unstable Saddle Point')
elif np.abs(dJ) < epsFIX:
    print('Multiple fixed points')
    if tJ > epsFIX:
        stb = 'unstable'
    elif tJ < -epsFIX:
        stb = 'stable'
    else:
        print('The whole plane is a fixed point')
else:
    if np.abs(tJ) < epsFIX:
        print('Center')
        
    else:
        if tJ > epsFIX:
            stb = 'unstable'
        else:
            stb = 'stable'
        if k < -epsFIX:
            print('spiral ' + stb)
        elif np.abs(k) < epsFIX:
            print('star, degenerate node ' + stb)
        else:
            print('Node ' + stb)

print('---------------------------------------------------------------------------------------')            
print('Determinant  = ',dJ,'; Trace = ', tJ,'; Square Trace-4*Determinant = ', k)
w, v =  np.linalg.eig(J)
print('---------------------------------------------------------------------------------------')
print('Eigenvalues are: ',w)
print('---------------------------------------------------------------------------------------')
print('Eigenvectors are : ', v)
# Out:
# spiral stable
# ---------------------------------------------------------------------------------------
# Determinant  =  2.0 ; Trace =  -2 ; Square Trace-4*Determinant =  -4.0
# ---------------------------------------------------------------------------------------
# Eigenvalues are:  [-1.+1.j -1.-1.j]
# ---------------------------------------------------------------------------------------
# Eigenvectors are :  [[-0.40824829-0.40824829j -0.40824829+0.40824829j]
#  [ 0.81649658+0.j          0.81649658-0.j        ]]

# %%
a, b, c, d = 3, -4, -1, -1

J = np.matrix([[a,b],[c,d]])
dJ = np.linalg.det(J)
tJ = np.trace(J)
k = tJ**2 - 4*dJ
epsFIX = 1e-6

if dJ < -epsFIX:
    print(' Unstable Saddle Point')
elif np.abs(dJ) < epsFIX:
    print('Multiple fixed points')
    if tJ > epsFIX:
        stb = 'unstable'
    elif tJ < -epsFIX:
        stb = 'stable'
    else:
        print('The whole plane is a fixed point')
else:
    if np.abs(tJ) < epsFIX:
        print('Center')
        
    else:
        if tJ > epsFIX:
            stb = 'unstable'
        else:
            stb = 'stable'
        if k < -epsFIX:
            print('spiral ' + stb)
        elif np.abs(k) < epsFIX:
            print('star, degenerate node ' + stb)
        else:
            print('Node ' + stb)
print('---------------------------------------------------------------------------------------')            
print('Determinant  = ',dJ,'; Trace = ', tJ,'; Square Trace-4*Determinant = ', k)
w, v =  np.linalg.eig(J)
print('---------------------------------------------------------------------------------------')
print('Eigenvalues are: ',w)
print('---------------------------------------------------------------------------------------')
print('Eigenvectors are : ', v)
# Out:
#  Unstable Saddle Point
# ---------------------------------------------------------------------------------------
# Determinant  =  -6.999999999999999 ; Trace =  2 ; Square Trace-4*Determinant =  31.999999999999996
# ---------------------------------------------------------------------------------------
# Eigenvalues are:  [ 3.82842712 -1.82842712]
# ---------------------------------------------------------------------------------------
# Eigenvectors are :  [[ 0.97921956  0.63795197]
#  [-0.20280301  0.77007615]]

# %%
a, b, c, d = 5, 2, -17, -5
J = np.matrix([[a,b],[c,d]])
dJ = np.linalg.det(J)
tJ = np.trace(J)
k = tJ**2 - 4*dJ
epsFIX = 1e-6

if dJ < -epsFIX:
    print(' Unstable Saddle Point')
elif np.abs(dJ) < epsFIX:
    print('Multiple fixed points')
    if tJ > epsFIX:
        stb = 'unstable'
    elif tJ < -epsFIX:
        stb = 'stable'
    else:
        print('The whole plane is a fixed point')
else:
    if np.abs(tJ) < epsFIX:
        print('Center')
        
    else:
        if tJ > epsFIX:
            stb = 'unstable'
        else:
            stb = 'stable'
        if k < -epsFIX:
            print('spiral ' + stb)
        elif np.abs(k) < epsFIX:
            print('star, degenerate node ' + stb)
        else:
            print('Node ' + stb)
print('---------------------------------------------------------------------------------------')            
print('Determinant  = ',dJ,'; Trace = ', tJ,'; Square Trace-4*Determinant = ', k)
w, v =  np.linalg.eig(J)
print('---------------------------------------------------------------------------------------')
print('Eigenvalues are: ',w)
print('---------------------------------------------------------------------------------------')
print('Eigenvectors are : ', v)
# Out:
# Center
# ---------------------------------------------------------------------------------------
# Determinant  =  8.999999999999998 ; Trace =  0 ; Square Trace-4*Determinant =  -35.99999999999999
# ---------------------------------------------------------------------------------------
# Eigenvalues are:  [-7.81249853e-17+3.j -7.81249853e-17-3.j]
# ---------------------------------------------------------------------------------------
# Eigenvectors are :  [[-0.27820744-0.16692447j -0.27820744+0.16692447j]
#  [ 0.9459053 +0.j          0.9459053 -0.j        ]]

# %%
a, b, c, d = 4, -3, 8, -6

J = np.matrix([[a,b],[c,d]])
dJ = np.linalg.det(J)
tJ = np.trace(J)
k = tJ**2 - 4*dJ
epsFIX = 1e-6

if dJ < -epsFIX:
    print(' Unstable Saddle Point')
elif np.abs(dJ) < epsFIX:
    print('Multiple fixed points')
    if tJ > epsFIX:
        stb = 'unstable'
    elif tJ < -epsFIX:
        stb = 'stable'
    else:
        print('The whole plane is a fixed point')
else:
    if np.abs(tJ) < epsFIX:
        print('Center')
        
    else:
        if tJ > epsFIX:
            stb = 'unstable'
        else:
            stb = 'stable'
        if k < -epsFIX:
            print('spiral ' + stb)
        elif np.abs(k) < epsFIX:
            print('star, degenerate node ' + stb)
        else:
            print('Node ' + stb)
print('---------------------------------------------------------------------------------------')            
print('Determinant  = ',dJ,'; Trace = ', tJ,'; Square Trace-4*Determinant = ', k)
w, v =  np.linalg.eig(J)
print('---------------------------------------------------------------------------------------')
print('Eigenvalues are: ',w)
print('---------------------------------------------------------------------------------------')
print('Eigenvectors are : ', v)
# Out:
# Multiple fixed points
# ---------------------------------------------------------------------------------------
# Determinant  =  0.0 ; Trace =  -2 ; Square Trace-4*Determinant =  4.0
# ---------------------------------------------------------------------------------------
# Eigenvalues are:  [ 0. -2.]
# ---------------------------------------------------------------------------------------
# Eigenvectors are :  [[0.6        0.4472136 ]
#  [0.8        0.89442719]]

# %% [markdown]
# ## 2 PHASE DIAGRAM WITH FIXED 2D

# %%
a, b, c, d = 0, 1, -2, -2

def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]


ts = np.linspace(0, 4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic: 
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:, 0], xs[:, 1], 'r-')


plt.xlabel('x')
plt.ylabel('y')
plt.tick_params()
plt.xlim(-1,1)
plt.ylim(-1,1)



X, Y = np.mgrid[-1:1:10j, -1:1:10j]
u = a+X + b*Y
v = c*X + d*Y
plt.quiver(X, Y, u, v, color='b')
plt.show()

# %%
a, b, c, d = 3, -4, -1, -1

def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]


ts = np.linspace(0, 4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic: 
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:, 0], xs[:, 1], 'r-')


plt.xlabel('x')
plt.ylabel('y')
plt.tick_params()
plt.xlim(-1,1)
plt.ylim(-1,1)


X, Y = np.mgrid[-1:1:10j, -1:1:10j]
u = a+X + b*Y
v = c*X + d*Y
plt.quiver(X, Y, u, v, color='b')
plt.show()

# %%
a, b, c, d = 5, 2, -17, -5

def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]


ts = np.linspace(0, 4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic: 
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:, 0], xs[:, 1], 'r-')


plt.xlabel('x')
plt.ylabel('y')
plt.tick_params()
plt.xlim(-1,1)
plt.ylim(-1,1)



X, Y = np.mgrid[-1:1:10j, -1:1:10j]
u = a+X + b*Y
v = c*X + d*Y
plt.quiver(X, Y, u, v, color='b')
plt.show()

# %%
a, b, c, d = 4, -3, 8, -6

def dx_dt(x, t):
    return [a*x[0] + b*x[1], c*x[0] + d*x[1]]


ts = np.linspace(0, 4, 100)
ic = np.linspace(-1, 1, 5)
for r in ic: 
    for s in ic:
        x0 = [r, s]
        xs = odeint(dx_dt, x0, ts)
        plt.plot(xs[:, 0], xs[:, 1], 'r-')


plt.xlabel('x')
plt.ylabel('y')
plt.tick_params()
plt.xlim(-1,1)
plt.ylim(-1,1)


X, Y = np.mgrid[-1:1:10j, -1:1:10j]
u = a+X + b*Y
v = c*X + d*Y
plt.quiver(X, Y, u, v, color='b')
plt.show()
